# %%
from xml.etree import ElementTree as ET

tweet = ET.parse("C:/Users/Maxime/Documents/Master_MEDAS/Fouille_de_donnees/Projet_datamining/projet_datamining/source/cmr-presidentielle2017-tei-v1.xml")

# %%
root = tweet.getroot()
root.attrib
# Out:
# {}

# %% [raw]
# Récupération des candidats.

# %%
ns = {'tei': 'http://www.tei-c.org/ns/1.0'}

for candidat in root.findall(".//tei:person/tei:persName/tei:name", ns):
    print(candidat.text)
# Out:
# Jean-Luc Mélenchon
# N. Dupont-Aignan
# Emmanuel Macron
# François Fillon
# Jacques Cheminade
# Jean Lassalle
# Marine Le Pen
# Nathalie Arthaud
# Philippe Poutou
# François Asselineau
# Benoît Hamon

# %% [raw]
# Récupération des id des candidats

# %%
for id in root.findall(".//tei:listPerson/tei:person", ns):
    print(id.attrib)
# Out:
# {'{http://www.w3.org/XML/1998/namespace}id': 'cmr-présidentielle-p80820758'}
# {'{http://www.w3.org/XML/1998/namespace}id': 'cmr-présidentielle-p38170599'}
# {'{http://www.w3.org/XML/1998/namespace}id': 'cmr-présidentielle-p1976143068'}
# {'{http://www.w3.org/XML/1998/namespace}id': 'cmr-présidentielle-p551669623'}
# {'{http://www.w3.org/XML/1998/namespace}id': 'cmr-présidentielle-p150201042'}
# {'{http://www.w3.org/XML/1998/namespace}id': 'cmr-présidentielle-p102722347'}
# {'{http://www.w3.org/XML/1998/namespace}id': 'cmr-présidentielle-p217749896'}
# {'{http://www.w3.org/XML/1998/namespace}id': 'cmr-présidentielle-p1003575248'}
# {'{http://www.w3.org/XML/1998/namespace}id': 'cmr-présidentielle-p374392774'}
# {'{http://www.w3.org/XML/1998/namespace}id': 'cmr-présidentielle-p200659061'}
# {'{http://www.w3.org/XML/1998/namespace}id': 'cmr-présidentielle-p14389177'}

# %% [raw]
# Récupération des tweets de Jean-Luc Mélenchon

# %%
tweet_JLM = open("C:/Users/Maxime/Documents/Master_MEDAS/Fouille_de_donnees/Projet_datamining/projet_datamining/data/tweet_Melenchon.txt", "w", encoding="utf-8")

for twText in root.findall('.//*[@who="#cmr-présidentielle-p80820758"]/tei:p', ns):

    text = "".join(twText.itertext())

    tweet_JLM.write(text)
    
tweet_JLM.close()

# %% [raw]
# Récupération des tweets de N. Dupont-Aignan

# %%
tweet_NDA = open("C:/Users/Maxime/Documents/Master_MEDAS/Fouille_de_donnees/Projet_datamining/projet_datamining/data/tweet_Dupont-Aignan.txt", "w", encoding="utf-8")

for twText in root.findall('.//*[@who="#cmr-présidentielle-p38170599"]/tei:p', ns):

    text = "".join(twText.itertext())

    tweet_NDA.write(text)
    
tweet_NDA.close()

# %% [raw]
# Récupération des tweets d'Emmanuel Macron

# %%
tweet_EMA = open("C:/Users/Maxime/Documents/Master_MEDAS/Fouille_de_donnees/Projet_datamining/projet_datamining/data/tweet_Macron.txt", "w", encoding="utf-8")

for twText in root.findall('.//*[@who="#cmr-présidentielle-p1976143068"]/tei:p', ns):

    text = "".join(twText.itertext())

    tweet_EMA.write(text)
    
tweet_EMA.close()

# %% [raw]
# Récupération des tweets de François Fillon

# %%
tweet_FFI = open("C:/Users/Maxime/Documents/Master_MEDAS/Fouille_de_donnees/Projet_datamining/projet_datamining/data/tweet_Fillon.txt", "w", encoding="utf-8")

for twText in root.findall('.//*[@who="#cmr-présidentielle-p551669623"]/tei:p', ns):

    text = "".join(twText.itertext())

    tweet_FFI.write(text)

tweet_FFI.close()

# %% [raw]
# Récupération des tweets de Jacques Cheminade

# %%
tweet_CCH = open("C:/Users/Maxime/Documents/Master_MEDAS/Fouille_de_donnees/Projet_datamining/projet_datamining/data/tweet_Cheminade.txt", "w", encoding="utf-8")

for twText in root.findall('.//*[@who="#cmr-présidentielle-p150201042"]/tei:p', ns):

    text = "".join(twText.itertext())

    tweet_CCH.write(text)
    
tweet_CCH.close()

# %% [raw]
# Récupération des tweets de Jean Lassalle

# %%
tweet_JLA = open("C:/Users/Maxime/Documents/Master_MEDAS/Fouille_de_donnees/Projet_datamining/projet_datamining/data/tweet_Lassalle.txt", "w", encoding="utf-8")

for twText in root.findall('.//*[@who="#cmr-présidentielle-p102722347"]/tei:p', ns):

    text = "".join(twText.itertext())

    tweet_JLA.write(text)
    
tweet_JLA.close()

# %% [raw]
# Récupération des tweets de Marine Le Pen

# %%
tweet_MLP = open("C:/Users/Maxime/Documents/Master_MEDAS/Fouille_de_donnees/Projet_datamining/projet_datamining/data/tweet_Le_Pen.txt", "w", encoding="utf-8")

for twText in root.findall('.//*[@who="#cmr-présidentielle-p217749896"]/tei:p', ns):

    text = "".join(twText.itertext())

    tweet_MLP.write(text)
    
tweet_MLP.close()

# %% [raw]
# Récupération des tweets de Nathalie Arthaud

# %%
tweet_NAR = open("C:/Users/Maxime/Documents/Master_MEDAS/Fouille_de_donnees/Projet_datamining/projet_datamining/data/tweet_Artaud.txt", "w", encoding="utf-8")

for twText in root.findall('.//*[@who="#cmr-présidentielle-p1003575248"]/tei:p', ns):

    text = "".join(twText.itertext())

    tweet_NAR.write(text)
    
tweet_NAR.close()

# %% [raw]
# Récupération des tweets de Philippe Poutou

# %%
tweet_PPO = open("C:/Users/Maxime/Documents/Master_MEDAS/Fouille_de_donnees/Projet_datamining/projet_datamining/data/tweet_Poutou.txt", "w", encoding="utf-8")

for twText in root.findall('.//*[@who="#cmr-présidentielle-p374392774"]/tei:p', ns):

    text = "".join(twText.itertext())

    tweet_PPO.write(text)
    
tweet_PPO.close()

# %% [raw]
# Récupération des tweets de François Asselineau

# %%
tweet_FAS = open("C:/Users/Maxime/Documents/Master_MEDAS/Fouille_de_donnees/Projet_datamining/projet_datamining/data/tweet_Asselineau.txt", "w", encoding="utf-8")

for twText in root.findall('.//*[@who="#cmr-présidentielle-p200659061"]/tei:p', ns):

    text = "".join(twText.itertext())

    tweet_FAS.write(text)
    
tweet_FAS.close()

# %% [raw]
# Récupération des tweets de Benoît Hamon

# %%
tweet_BHA = open("C:/Users/Maxime/Documents/Master_MEDAS/Fouille_de_donnees/Projet_datamining/projet_datamining/data/tweet_Hamon.txt", "w", encoding="utf-8")

for twText in root.findall('.//*[@who="#cmr-présidentielle-p14389177"]/tei:p', ns):

    text = "".join(twText.itertext())

    tweet_BHA.write(text)
    
tweet_BHA.close()

# %% [raw]
# Je me déplace à la racine et je regarde les enfants. Ici il y en a 2 "teiHeader" et "text".

# %%
for child in root:
    print(child.tag, child.attrib)
# Out:
# {http://www.tei-c.org/ns/1.0}teiHeader {}
# {http://www.tei-c.org/ns/1.0}text {}

# %% [raw]
#  On cherche à connaitre toutes les arborescences.

# %%
[elem.tag for elem in root.iter()]
# Out:
# ['{http://www.tei-c.org/ns/1.0}TEI',
#  '{http://www.tei-c.org/ns/1.0}teiHeader',
#  '{http://www.tei-c.org/ns/1.0}fileDesc',
#  '{http://www.tei-c.org/ns/1.0}titleStmt',
#  '{http://www.tei-c.org/ns/1.0}title',
#  '{http://www.tei-c.org/ns/1.0}idno',
#  '{http://www.tei-c.org/ns/1.0}bibl',
#  '{http://www.tei-c.org/ns/1.0}desc',
#  '{http://www.tei-c.org/ns/1.0}ref',
#  '{http://www.tei-c.org/ns/1.0}name',
#  '{http://www.tei-c.org/ns/1.0}ref',
#  '{http://www.tei-c.org/ns/1.0}ref',
#  '{http://www.tei-c.org/ns/1.0}desc',
#  '{http://www.tei-c.org/ns/1.0}ref',
#  '{http://www.tei-c.org/ns/1.0}name',
#  '{http://www.tei-c.org/ns/1.0}ref',
#  '{http://www.tei-c.org/ns/1.0}ref',
#  '{http://www.tei-c.org/ns/1.0}principal',
#  '{http://www.tei-c.org/ns/1.0}persName',
#  '{http://www.tei-c.org/ns/1.0}name',
#  '{http://www.tei-c.org/ns/1.0}surname',
#  '{http://www.tei-c.org/ns/1.0}email',
#  '{http://www.tei-c.org/ns/1.0}orgName',
#  '{http://www.tei-c.org/ns/1.0}orgName',
# ...

# %%
for candidat in root.findall('.//*{http://www.tei-c.org/ns/1.0}persName/{http://www.tei-c.org/ns/1.0}name'):
    print(candidat.text)
# Out:
# Julien
# Julien
# Nader
# Abdulhafiz
# Boris
# Claudia
# Nader
# Abdulhafiz
# Boris
# Jean-Luc Mélenchon
# N. Dupont-Aignan
# Emmanuel Macron
# François Fillon
# Jacques Cheminade
# Jean Lassalle
# Marine Le Pen
# Nathalie Arthaud
# Philippe Poutou
# François Asselineau
# Benoît Hamon

# %%
root[0][0][4][0][0][0][0].text
# Out:
# 'Jean-Luc Mélenchon'

# %%
for i in root[0][0][4][0]:
    print (root[0][0][4][i][0][0][0].text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-3f5b2d371fe6> in <module>
#       1 for i in root[0][0][4][0]:
# ----> 2     print (root[0][0][4][i][0][0][0].text)
#
# src/lxml/parser.pxi in lxml.etree._BaseParser._parseDocFromFile()
#
# TypeError: 'lxml.etree._Element' object cannot be interpreted as an integer

# %%
class Team:
    def __init__(self, name):
        #self.idTeam = idTeam
        self.name = name

# %%
My_teams = []
for item in data:
    
    team = item['homeTeam']
    
    idTeam = team['id']
    name = team['name']
    
    My_teams.append(Team(idTeam, name))

# %% [markdown]
# # Création de la classe Tweet

# %%
class Tweet(object):
    def __init__(self, id_tweet, id_candidat, date, oscars=[]):
        self.id_tweet = id_tweet
        self.id_candidat = id_candidat
        self.date = date
        self.oscars = oscars
